# %% [markdown]
# Exemplo
# [Documento de referência](https://pt.scribd.com/document/756310038/Lugar-Geometrico-das-Raizes)

# %%
import math
import cmath
import sympy as sp
from sympy import symbols, I, Abs
from sympy.physics.control import TransferFunction
import numpy as np

# %%
s, k = sp.symbols('s k')
ganho = k

# %%
print("Forneça a função de transferência...")
numerador_txt = input("Digite o numerador: ") # Digite: s + 1
denominador_txt = input("Digite o denominador: ") # Digite: s**2 + 2*s

numerador_ft = sp.parse_expr(numerador_txt, local_dict={'s': s})
denominador_ft = sp.parse_expr(denominador_txt, local_dict={'s': s})

ft = TransferFunction(numerador_ft, denominador_ft, s)
print(ft)
# Out:
# Forneça a função de transferência...
# ValueError: Error from parse_expr with transformed code: ''
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#
#   File ~/Documents/2026.2/Projeto_de_Sistemas_de_Controle/LGR/.lgr/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3823 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[16], line 5
#     numerador_ft = sp.parse_expr(numerador_txt, local_dict={'s': s})
#
#   File ~/Documents/2026.2/Projeto_de_Sistemas_de_Controle/LGR/.lgr/lib/python3.12/site-packages/sympy/parsing/sympy_parser.py:1090 in parse_expr
#     raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
#   File ~/Documents/2026.2/Projeto_de_Sistemas_de_Controle/LGR/.lgr/lib/python3.12/site-packages/sympy/parsing/sympy_parser.py:1081 in parse_expr
#     rv = eval_expr(code, local_dict, global_dict)
#
#   File ~/Documents/2026.2/Projeto_de_Sistemas_de_Controle/LGR/.lgr/lib/python3.12/site-packages/sympy/parsing/sympy_parser.py:905 in eval_expr
#     expr = eval(
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
ponto_txt = input("Digite o ponto de teste (a+b*j): ")  # Digite: -3+4*j

ponto_si = sp.parse_expr(ponto_txt, local_dict={'j': sp.I})
print(ponto_si)
# Out:
# -2.19 + 2.89*I

# %%
freq = ft.eval_frequency(ponto_si)
M = sp.Abs(freq)
theta = cmath.phase(freq) * 180/np.pi # a fase deve ser em graus
# Tratamento para o angulo ser positivo
while theta < 0:
  theta += 360

print(f"M = {M}. Theta = {theta}")
# Out:
# M = 0.122884701523725. Theta = 179.80025397759138

# %%
# Testar se é LGR
while theta > 360:
  theta -= 360

if(theta > 175 and theta < 185): # 5 graus para erros de aproximação
  print("Fase certa!")
  K = 1/M
  print(f"O K que gera esse polo é {K}")
else:
  print("Não é LGR")
# Out:
# Fase certa!
# O K que gera esse polo é 8.13770947563340
